# %% [markdown]
# 幾何ではちょっと解けていないので，とりあえず，複素数平面で解きました。
#
# ![IMG_1075.JPG](attachment:IMG_1075.JPG)

# %%
b=0
# Out:
# <div><pre style="&#102;&#111;&#110;&#116;&#45;&#102;&#97;&#109;&#105;&#108;&#121;&#58;&#32;&#34;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#32;&#78;&#101;&#119;&#34;&#44;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#44;&#109;&#111;&#110;&#111;&#115;&#112;&#97;&#99;&#101;&#59;">&#48;</pre></div>

# %%
p=3
# Out:
# <div><pre style="&#102;&#111;&#110;&#116;&#45;&#102;&#97;&#109;&#105;&#108;&#121;&#58;&#32;&#34;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#32;&#78;&#101;&#119;&#34;&#44;&#67;&#111;&#117;&#114;&#105;&#101;&#114;&#44;&#109;&#111;&#110;&#111;&#115;&#112;&#97;&#99;&#101;&#59;">&#51;</pre></div>

# %%
Solve[16==(3+x)^2+3x^2,x]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
c=3+(Sqrt[37]-3)/2//Simplify
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
d=3+(Sqrt[37]-3)/4+(Sqrt[3] (Sqrt[37]-3)/4)I//Simplify
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
a=d*(1/2+Sqrt[3]I/2)//Simplify
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
ComplexExpand[ Re[d*t-a*s+c*r] ]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
ComplexExpand[ Im[d*t-a*s+c*(1-t)] ]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
Solve[{ComplexExpand[ Re[d*t-a*s-c*r] ]==0,ComplexExpand[ Im[d*t-a*s-c*r] ]==0,s+r==1},{s,t,r}]//Simplify
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>

# %%
%Simblify
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>
